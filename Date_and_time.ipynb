# %% [markdown]
# <a href="https://colab.research.google.com/github/shrey9903/modules_and_packages/blob/main/Date_and_time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import time


print('======'*15)
print('Date and time oprations:')
print('======'*15)





def Current_date_time():
    try:
        now=datetime.datetime.now()
        print("\n Current Date & Time:",now)
        print('======'*15)
    except Exception:
        print('Enter valid input!')
    return
def Diff_date_time():
    try:
        date1 = input("Enter the first date (YYYY-MM-DD): ")
        date2 = input("Enter the second date (YYYY-MM-DD): ")
        y1, m1, d1 = map(int, date1.split("-"))
        y2, m2, d2 = map(int, date2.split("-"))
        d1 = datetime.date(y1, m1, d1)
        d2 = datetime.date(y2, m2, d2)
        diff = abs((d2 - d1).days)
        print(f"Difference is {diff} ")
        print('======'*15)
        return
    except Exception:
        print('Enter valid input')
def Formate_date_time():
    return
def Stop_watch():
    try:
        print("Press ENTER to start the stopwatch")
        input()
        start_time = time.time()
        print("Stopwatch started... Press ENTER again to stop")
        input()
        end_time = time.time()

        elapsed = end_time - start_time
        print(f"Elapsed Time: {elapsed:.2f} seconds")
        print('======'*15)
        return
    except Exception:
        print('Enter valid input')


def Coun_timer():
    try:
        seconds = int(input("Enter time in seconds: "))
        for i in range(seconds, 0, -1):
            print(i, end="\r")
            time.sleep(1)

            print("Time's up!")
            print('======'*15)
        return
    except Exception:
        print('Enter valid input')

def date_time():
    while True:
        print("Choose an option:")

        print('\n1.Display current date and time  ')
        print('2.Calculate diffrence between tow dates/times ')
        print('3.Formate date into custome formate ')
        print('4.stopwatch')
        print('5.countdown timer')
        print('6.back to main menu')

        print('======'*15)
        option=int(input('Enter your option'))
        print('======'*15)

        match option:
            case 1:#Display current date and time
                Current_date_time()
            case 2:#Calculate diffrence between tow dates/times
                Diff_date_time()
            case 3:#Formate date into custome formate
                pass
            case 4:#stopwatch
                Stop_watch()
            case 5:#countdown timer
                Coun_timer()

            case 6:#back to main menu
                break
            case _:
                print("Enter valid choice")
    return

date_time()
# Out:
# ...
# Date and time oprations:
# ...
# Choose an option:
#
# 1.Display current date and time
# 2.Calculate diffrence between tow dates/times
# 3.Formate date into custome formate
# 4.stopwatch
# 5.countdown timer
# 6.back to main menu
# ...
# Enter your option1
# ...
#
#  Current Date & Time: 2026-03-27 12:01:36.734761
# ...
# Choose an option:
#
# 1.Display current date and time
# 2.Calculate diffrence between tow dates/times
# 3.Formate date into custome formate
# 4.stopwatch
# 5.countdown timer
# 6.back to main menu
# ...
# Enter your option2
# ...
# Enter the first date (YYYY-MM-DD): 2003-09-09
# Enter the second date (YYYY-MM-DD): 2003-08-31
# Difference is 9
# ...
# Choose an option:
#
# 1.Display current date and time
# 2.Calculate diffrence between tow dates/times
# 3.Formate date into custome formate
# 4.stopwatch
# 5.countdown timer
# 6.back to main menu
# ...
# Enter your option3
# ...
# Choose an option:
#
# 1.Display current date and time
# 2.Calculate diffrence between tow dates/times
# 3.Formate date into custome formate
# ...
